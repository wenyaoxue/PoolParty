# %% [markdown]
# # match something to synonym
# using thesaurus/dictionary data: https://drive.google.com/drive/folders/1v_o3wE-krj49hFY2v-2OWlWK-FZgFgg2, extracted using this notebook: https://colab.research.google.com/drive/1e4eHLKewBPx3nfAHrR1ImWtw2olXcRtR
