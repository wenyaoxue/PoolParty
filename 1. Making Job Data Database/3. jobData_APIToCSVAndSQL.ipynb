# %% [markdown]
# gets from API, +
# - limits to US (for the muse: 1/4 for each 1/4 US cities available)
# - removes HTML tags from the muse description
# - adds lon/lat from mapbox for the muse
# - if states are in the location, stores that value in its own column (removed from the location column)
# - add 4 columns with openai prompt text generation

# %% [markdown]
# # museReqStrs is a list of 4 strings
# museReqStrs is a list of 4 strings, where each includes the endpoint, then 1/4 of the US cities in The Muse's database (grouped alphabetically), then page=
# this is the request url, except the page # must be added
#
# one request sent with more cities doesn't work, error response object
#
# the strings were made by scraping The Muse's documentation page, using
# [this notebook](https://colab.research.google.com/drive/1E90-d0EFe6VUDCy1-Uc5CvL9bVo0HaUc)

# %%
#Aberdeen, MD to Dubuque, IA
museReqStr1 = "https://www.themuse.com/api/public/jobs?location=Aberdeen%2C%20MD&location=Aberdeen%2C%20SD&location=Aberdeen%2C%20WA&location=Abilene%2C%20TX&location=Ada%2C%20OK&location=Addison%2C%20IL&location=Addison%2C%20TX&location=Adelanto%2C%20CA&location=Adrian%2C%20MI&location=Agawam%2C%20MA&location=Agoura Hills%2C%20CA&location=Ahwatukee%2C%20AZ&location=Aiken%2C%20SC&location=Akron%2C%20OH&location=Alameda%2C%20CA&location=Alamogordo%2C%20NM&location=Albany%2C%20GA&location=Albany%2C%20NY&location=Albany%2C%20OR&location=Albemarle%2C%20NC&location=Albert Lea%2C%20MN&location=Albuquerque%2C%20NM&location=Alcoa%2C%20TN&location=Alexandria%2C%20LA&location=Alexandria%2C%20VA&location=Alice%2C%20TX&location=Allen Park%2C%20MI&location=Allentown%2C%20PA&location=Allen%2C%20TX&location=Alliance%2C%20OH&location=Alma%2C%20MI&location=Alpena%2C%20MI&location=Alpharetta%2C%20GA&location=Altamont%2C%20OR&location=Alton%2C%20IL&location=Altoona%2C%20PA&location=Altus%2C%20OK&location=Amarillo%2C%20TX&location=American Canyon%2C%20CA&location=American Fork%2C%20UT&location=Americus%2C%20GA&location=Ames%2C%20IA&location=Amherst%2C%20MA&location=Amsterdam%2C%20NY&location=Anchorage%2C%20AK&location=Anderson%2C%20IN&location=Anderson%2C%20SC&location=Andover%2C%20CT&location=Andover%2C%20MA&location=Angleton%2C%20TX&location=Anna Maria%2C%20FL&location=Annapolis Junction%2C%20MD&location=Annapolis%2C%20MD&location=Ann Arbor%2C%20MI&location=Ansonia%2C%20CT&location=Antelope%2C%20CA&location=Anthem%2C%20AZ&location=Antioch%2C%20CA&location=Antioch%2C%20TN&location=Apache Junction%2C%20AZ&location=Apopka%2C%20FL&location=Appleton%2C%20WI&location=Apple Valley%2C%20CA&location=Apple Valley%2C%20MN&location=Arcata%2C%20CA&location=Ardmore%2C%20OK&location=Arlington Heights%2C%20IL&location=Arlington%2C%20TX&location=Arlington%2C%20VA&location=Arvin%2C%20CA&location=Asbury Park%2C%20NJ&location=Ashburn%2C%20VA&location=Asheboro%2C%20NC&location=Asheville%2C%20NC&location=Ashford%2C%20CT&location=Ashland%2C%20OH&location=Ashland%2C%20OR&location=Ashland%2C%20VA&location=Asht
import pandas as pd
from google.colab import files
from datetime import datetime
from IPython.display import Image, display
import urllib
import re

from bs4 import BeautifulSoup
import json

# %%
def getVal(d, ks): #can test with d = {1:{2:{3:{4:{5:6}}}}}, ks = [0,3]
  d2 = d
  for i, k in enumerate(ks):
    if i == len(ks) - 1:
      return d2.get(k, "N/A")
    d2 = d2.get(k, {})

def unqFileName(base):
  now = datetime.now()
  # dd/mm/YY H:M:S
  dt_string = now.strftime("%d%m%Y_%H%M%S")
  return base + "_" + dt_string + ".csv"

def downloadOrDisplay(file, df, head=False):  
  download = ""
  while download != "Y" and download != "N":
    download = input("download? [y/n] --> ").upper()
  if download == "Y":
    fNm = unqFileName(file)
    df.to_csv(fNm, encoding='utf-8') 
    files.download(fNm)
  else:
    if head:
      display(df.head())
    else:
      display(df)

def locToLonLat(loc):
  locToCrdPs = {
      'access_token' : 'pk.eyJ1IjoiY3J5c3RhbHdlbiIsImEiOiJjbGFpcmNza20wNTk2M29yMHRuMjFic3lyIn0.ZMSsiDCPmlK_mNHDg_WwnQ'
  }
  locToCrdUrl = "https://api.mapbox.com/geocoding/v5/mapbox.places/"
  try:
    encoded_city = urllib.parse.quote(loc)  #changing special characters if there are any, eg #
    crdResp = requests.get(locToCrdUrl+ encoded_city + ".json?", params=locToCrdPs) 
    crdBbox = crdResp.json()['features'][0]['bbox']
    crdToMapPs = { 'access_token' : 'pk.eyJ1IjoiY3J5c3RhbHdlbiIsImEiOiJjbDhqamlhOHUwN2RvM29vMnJ4a2pvN3hvIn0.O5SnEDk2AOpTcBIgwmSsUg',
            'padding':'50,10,20'}
    lon = (crdBbox[0] + crdBbox[2])/2
    lat = (crdBbox[1] + crdBbox[3])/2
  except:
    lat = pd.NA
    lon = pd.NA
  return lon, lat

# %%
# !pip install openai

import openai

#openai.api_key = "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" #crystal's first key (note, a second key, or even a second account, with the same phone number, will not work anymore: quota is met)
#second key but won't work bc i don't have credits: openai.api_key = "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" #crystal's second key, but still doesn't matter, quota is totally done
openai.api_key = "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" #jamie's
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# i = what number this row is (just for printing error purposes), jobDesc = row["desc"]
# returns [workstr, hardskillsstr, softskillsstr, educationstr]
def addOpenAIFeatures(i, jobDesc):
  newFeatureVals = []
  jobDesc = jobDesc.replace('&amp;', '&')
  for newFeature in [("What will you be doing if you work with us?", "work", 50), 
                    ("What all is the most important background, experience, or knowledge you need to be successful?", "hardskills", 50),
                    ("What are the most important soft skills you need to be successful?", "softskills", 50),
                    ("What education do you need to work in this position?", "education", 20)]:
    done = False
    while not done:
      #print(newFeature[1], datetime.now(), end=' ')
      try:
        response = openai.Completion.create(
          model="text-davinci-002",
          prompt= jobDesc + " " + newFeature[0],
          temperature=0.7,
          max_tokens=newFeature[2],
          top_p=1,
          frequency_penalty=0,
          presence_penalty=0
        )
        done = True
      except:
        print(datetime.now(), "openAiFeature didn't work", i, newFeature, "sleeping 60 seconds")
        time.sleep(60)
    newFeatureStr = response["choices"][0]["text"].strip()
    newFeatureVals.append(newFeatureStr)

  return newFeatureVals

# %% [markdown]
# # State + Abbreviation dictionaries
# - states_keyabrv[state] = abbrev
# - states_keyfull[abbrev] = state

# %%
states_keyfull = {"Alaska" : "AK", 
"Alabama" : "AL",
"Arkansas" : "AR", 
"Arizona" : "AZ",
"California" : "CA",
"Colorado" : "CO",
"Connecticut" : "CT",
"District of Columbia" : "DC",
"Delaware" : "DE",
"Florida" : "FL",
"Georgia" : "GA",
"Guam" : "GU",
"Hawaii" : "HI",
"Iowa" : "IA",
"Idaho" : "ID",
"Illinois" : "IL",
"Indiana" : "IN",
"Kansas" : "KS",
"Kentucky" : "KY",
"Louisiana" : "LA",
"Massachusetts" : "MA",
"Maryland" : "MD",
"Maine" : "ME",
"Michigan" : "MI",
"Minnesota" : "MN",
"Missouri" : "MO",
"Mississippi" : "MS",
"Montana" : "MT",
"North Carolina" : "NC",
"North Dakota" : "ND",
"Nebraska" : "NE",
"New Hampshire" : "NH",
"New Jersey" : "NJ",
"New Mexico" : "NM",
"Nevada" : "NV",
"New York" : "NY",
"Ohio" : "OH",
"Oklahoma" : "OK",
"Oregon" : "OR",
"Pennsylvania" : "PA",
"Puerto Rico" : "PR",
"Rhode Island" : "RI",
"South Carolina" : "SC",
"South Dakota" : "SD",
"Tennessee" : "TN",
"Texas" : "TX",
"Utah" : "UT",
"Virginia" : "VA",
"Virgin Islands" : "VI",
"Vermont" : "VT",
"Washington" : "WA",
"Wisconsin" : "WI",
"West Virginia" : "WV",
"Wyoming" : "WY"}

states_keyabrv = {}

for key, val in states_keyfull.items():
  states_keyabrv[val] = key

# %% [markdown]
# # Jobs dataframe
# info that we can get from the API response objects
#
#
#
# *   declare the jobs dictionary (features for each job)
# *   adzResAttrs(jobs, res) - put the features from an adzuna result into jobs
# *   museResAttrs(jobs, res, loc) - put the features from a muse result into jobs

# %%
jobs = {}
for field in ['title', 'cat', 'comp', 'loc', 'state', 'desc', 'redURL', 'lon', 'lat', 'pstDate', 'salaryPredicted', 'levels', 'API', 'work', 'hardskills', 'softskills', 'education']:
  jobs[field] = [] #if using user picked filtration, can possibly keep track of which ones each job passes/fails and aggregate

# %%
def adzResAttrs(jobs, res, i):
  jobs['title'].append(getVal(res, ['title']))
  jobs['cat'].append(getVal(res, ['category', 'label']))
  comp = getVal(res, ['company', 'display_name'])
  jobs['comp'].append(comp)  
  loc = getVal(res, ['location', 'area'])
  if loc == "N/A":
    loc = [getVal(res, ['display_name'])]
  
  locArr = list(reversed(loc))
  if "US" in locArr: locArr.remove("US")
  state = pd.NA
  remI = -1
  for i, locPart in enumerate(locArr):
    if states_keyfull.get(locPart, 0) != 0:
      state = locPart
      remI = i
      break
  if remI != -1:
    locArr.pop(remI)
  jobs['loc'].append(", ".join(locArr))
  jobs['state'].append(state)

  desc = getVal(res, ['description']) #lots of potention for cleaning this up, extracting keywords, find most important parts, use thesaurus APIs, ...
  for tag in ["Summary: ", "Job Description ", "ROLE DESCRIPTION ", "Application Instructions ", "Position Purpose: "]:
    desc = desc.replace(tag, "")
  jobs['desc'].append(desc)

  
  openAiFtrs = addOpenAIFeatures( i, desc )
  jobs["work"].append(openAiFtrs[0])
  jobs["hardskills"].append(openAiFtrs[1])
  jobs["softskills"].append(openAiFtrs[2])
  jobs["education"].append(openAiFtrs[3])

  jobs['redURL'].append(getVal(res, ['redirect_url']))
  jobs['lon'].append(getVal(res, ['longitude']))
  jobs['lat'].append(getVal(res, ['latitude'])) #can send to google maps, compare to user location
  pstDate = getVal(res, ['created']).split("T")[0]
  jobs['pstDate'].append(pstDate)
  jobs['salaryPredicted'].append(getVal(res, ['salary_is_predicted']))

  jobs['levels'].append(pd.NA)
  jobs['API'].append("adzuna")

def museResAttrs(jobs, res, loc, i):
  jobs['title'].append(getVal(res, ['name']))
  cats = res.get("categories", [{}])
  cat1 = cats[0] if len(cats) > 0 else {}
  jobs['cat'].append(  getVal(cat1, ['name'])  )
  jobs['comp'].append(getVal(res, ['company', 'name']))

  locArr = loc.replace(', US', '').replace('US', '').split(', ')
  stateAbrv = locArr[0] if len(locArr) == 1 else locArr[1]
  jobs['state'].append( states_keyabrv.get(stateAbrv, stateAbrv) )
  jobs['loc'].append(locArr[0])

  desc = getVal(res, ['contents'])
  
  desc2 = desc
  for tag in list(set(re.findall('</*[a-z]*\d*>', desc)))+['\n']:
    desc2 = desc2.replace(tag, " ")

  # CLEAN !! need to remove html tags and things
  jobs['desc'].append(    desc2.strip()    )  #this is html lots of potential for cleaning this up, extracting keywords, find most important parts, use thesaurus APIs, ...

  openAiFtrs = addOpenAIFeatures( i, desc2.strip() )
  jobs["work"].append(openAiFtrs[0])
  jobs["hardskills"].append(openAiFtrs[1])
  jobs["softskills"].append(openAiFtrs[2])
  jobs["education"].append(openAiFtrs[3])

  jobs['redURL'].append(getVal(res, ['refs', 'landing_page']))      

  lon, lat = locToLonLat(loc)
  jobs['lon'].append(lon)
  jobs['lat'].append(lat) #can send to google maps, compare to user location

  jobs['pstDate'].append(  getVal(res, ['publication_date']).split("T")[0]  )
  jobs['salaryPredicted'].append(0)
  jobs['levels'].append(  " AND ".join([lvl.get("name", pd.NA) for lvl in res.get("levels",    [])])     )
  jobs['API'].append("themuse")

# %% [markdown]
# # API requests
# make the requests until you get enough results, send the request, add them to jobs until you have enough
# *   getAdzunaJobs(country_code, n, jobs)
# *   getMuseJobs(n, jobs)
# *   jobs --> df, download as csv

# %%
#send search keyword, country, and number of listings
#get job title, category, company, location, description, link, longitude, latitude, post-date

def getAdzunaJobs(country_code, n, jobs):
#def getAdzunaJobs(search_field, country_code, n, jobs):                                 #returns a pandas dataframe of n search_field jobs from country_code
  #documentation: https://developer.adzuna.com/overview
  numJobs = 0

  params = {
    #i think this token was maxed out
    'app_id': 'e25d9d98',
    'app_key': 'd3308f10a71b2ea8b049eafd60834da0',
    #'what': search_field
  }
  pg = 1
  while (True):
    url = 'https://api.adzuna.com/v1/api/jobs/'+ country_code +'/search/' + str(pg)
    resp = requests.get(url,params=params)
    for res in resp.json()['results']:
      if numJobs % 10 == 0:
        print("\n", datetime.now(), end = '\t')
      print(numJobs, end = '\t')
      adzResAttrs(jobs, res, numJobs)
      numJobs += 1
      if (numJobs == n):
        return
    pg += 1

# %%
#send search keyword, country, and number of listings
#get job title, category, company, location, description, link, longitude, latitude, post-date

def getMuseJobs(n, jobs): #returns a pandas dataframe of n search_field jobs from country_code
  #documentation: https://www.themuse.com/developers/api/v2

  i = 0 #4 request strings to cover all US cities (it won't work if there's too many cities), get n//4 jobs from each request
  numJobs = 0
  pg = 1
  while (True):
    resp = requests.get(museReqStrs[i] + str(pg))
    for res in json.loads(resp.content.decode('utf-8'))['results']:
      locs = [loc.get("name", pd.NA) for loc in res.get("locations", [])]
      for loc in locs:
        if (i*(n//4) + numJobs) % 10 == 0:
          print("\n", datetime.now(), end = '\t')
        print(i*(n//4) + numJobs, end = '\t')
        museResAttrs(jobs, res, loc, i*(n//4) + numJobs)
        numJobs += 1
        if (numJobs == n//4):
          if i == 3:
            return
          numJobs = 0
          pg = 1
          i += 1
    pg += 1

# %%
getMuseJobs(4, jobs)
getAdzunaJobs("us", 4, jobs)

df = pd.DataFrame.from_dict(jobs)
# Out:
#  2022-12-12 03:20:25.928591	0	1	2	3
#  2022-12-12 03:20:50.942035	0	1	2	3

# %%
downloadOrDisplay("museAndAdzunaJobs", df)
# Out:
# download? [y/n] --> n
#                                                title  \
# 0  Engineer Commissioning Coordinator- II - Fire/...
# 1  Service Specialist II - Smart Buildings / Auto...
# 2             Director of Battery Industry Solutions
# 3              Service Coordinator - Smart Buildings
# 4                                      Driver Helper
# 5                      Package Handler – Hiring ASAP
# 6                           Seasonal Delivery Driver
# 7       Personal Vehicle Driver - Hiring Immediately
#
#                           cat     comp                                loc  \
# 0     Science and Engineering  Siemens                         Cincinnati
# 1                Construction  Siemens                      Buffalo Grove
# 2        Software Engineering  Siemens                             Austin
# 3        Software Engineering  Siemens                         Des Moines
# 4                 Travel Jobs      UPS                 Wells, York County
# ...

# %% [markdown]
# # Dataframe To SQL

# %%
# Install the SQLAlchemy library if it is not installed
# !sudo apt-get install python3-dev libmysqlclient-dev > /dev/null
# !pip install mysqlclient > /dev/null
# !sudo pip3 install -U sql_magic > /dev/null
# !pip install psycopg2-binary > /dev/null

# %%
from sqlalchemy import create_engine

# %%
# Connect to the MySQL, but without selecting a database

#see appendix!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
import pandas as pd
from google.colab import files
import io

# %%
#if not running all in order: could upload a different one to be df, otherwise df is defined from transformed API requests

#uploaded = files.upload() #just upload 1 file, download from here: https://drive.google.com/drive/folders/18dEvVuQrfJRZP2pSZLhCIHLQMAJomKVr
#many cells assume using v2
#df = pd.read_csv(io.BytesIO(uploaded[list(uploaded.keys())[0]]))

# %%
df.to_sql('jobdataTEST', if_exists='replace', con=engine) #could do append or fail
