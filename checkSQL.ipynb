# %%
# Install the SQLAlchemy library if it is not installed
# !sudo apt-get install python3-dev libmysqlclient-dev > /dev/null
# !pip install mysqlclient > /dev/null
# !sudo pip3 install -U sql_magic > /dev/null
# !pip install psycopg2-binary > /dev/null

# %%
from sqlalchemy import create_engine

# %%
# Connect to the MySQL, but without selecting a database

#see appendix!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
import pandas as pd

# %%
pd.read_sql('SELECT * FROM jobdata', con=engine)
# Out:
#       index                                              title  \
# 0         0                             Field Service Engineer
# 1         1                Sr. Verification Consultant- Remote
# 2         2  Director of Software Engineering - EV TaaS - E...
# 3         3           DCS/MES Project Manager - Small Projects
# 4         4  Corporate Account Manager  (Vertical Market Au...
# ...     ...                                                ...
# 1995   1995                                                EMT
# 1996   1996   Industrial Mechanic-Top Pay 41/hr-PensionBenefit
# 1997   1997                                        Lyft Driver
# 1998   1998              Dedicated Regional Class A CDL Driver
# 1999   1999                   Lyft Driver - Signing up is Easy
#
#                             cat     comp                          loc  \
# 0       Science and Engineering  Siemens                    Baltimore
# 1     Advertising and Marketing  Siemens                         Cary
# 2          Software Engineering  Siemens                      Atlanta
# 3            Project Management  Siemens                 Collegeville
# 4            Account Management  Siemens                     Cadillac
# ...                         ...      ...                          ...
# 1995  Healthcare & Nursing Jobs      AMR    Superior, Nuckolls County
# 1996           Engineering Jobs      UPS      Fremont, Alameda County
# 1997                Travel Jobs     Lyft      Kaysville, Davis County
# 1998                Travel Jobs  Carvana  Golf Manor, Hamilton County
# 1999                Travel Jobs     Lyft        Oakley, Summit County
#
#                                                    desc  \
# 0     Russelectric , A Siemens Business, is a leadin...
# 1     At Siemens we are always challengingourselves ...
# 2     &gt;&gt;THIS IS A REMOTE POSITION&lt;&lt;    W...
# 3     Position Overview     The DCS/MES Project Mana...
# 4     Siemens is looking fora  Corporate Account Man...
# ...                                                 ...
# 1995  More Information about this Job: EMT BASIC (Em...
# 1996  Industrial Mechanic-Top Pay 41/hr-PensionBenef...
# 1997  Earn $1,600 in Salt Lake City when you give 14...
# 1998  IMMEDIATELY HIRING Experienced CDL A Local, De...
# 1999  Earn $1,600 in Salt Lake City when you give 14...
#
#                                                  redURL         lon  \
# 0     https://www.themuse.com/jobs/siemens/field-ser...  -76.602540
# 1     https://www.themuse.com/jobs/siemens/sr-verifi...  -78.831704
# 2     https://www.themuse.com/jobs/siemens/director-...  -84.438153
# 3     https://www.themuse.com/jobs/siemens/dcsmes-pr...  -75.426139
# 4     https://www.themuse.com/jobs/siemens/corporate...  -85.548179
# ...                                                 ...         ...
# 1995  https://www.adzuna.com/land/ad/3691789873?se=Q...  -98.066640
# 1996  https://www.adzuna.com/land/ad/3654185751?se=Q... -122.014570
# 1997  https://www.adzuna.com/land/ad/3697273974?se=Q... -111.936136
# 1998  https://www.adzuna.com/land/ad/3698687983?se=Q...  -84.448830
# 1999  https://www.adzuna.com/land/ad/3697274800?se=Q... -111.283871
#
#             lat     pstDate  salaryPredicted        levels      API  \
# 0     39.320037  2022-08-22                0     Mid Level  themuse
# 1     35.778115  2022-11-02                0  Senior Level  themuse
# 2     33.752892  2022-11-10                0  Senior Level  themuse
# 3     40.187957  2022-10-31                0     Mid Level  themuse
# 4     44.257184  2022-10-07                0  Senior Level  themuse
# ...         ...         ...              ...           ...      ...
# 1995  40.022701  2022-11-15                0          None   adzuna
# 1996  37.556200  2022-11-03                0          None   adzuna
# 1997  41.029456  2022-11-16                0          None   adzuna
# 1998  39.194440  2022-11-17                0          None   adzuna
# 1999  40.721713  2022-11-16                0          None   adzuna
#
#                State                                               work  \
# 0           Maryland  Responsible for providing on-site support for ...
# 1     North Carolina  You will be supporting a team of engineers, sc...
# 2            Georgia  Siemens Smart Infrastructure is a leading glob...
# 3       Pennsylvania  The DCS/MES Project Manager - Small Projects i...
# 4           Michigan  We firmly believe that it is our people that w...
# ...              ...                                                ...
# 1995        Nebraska  Responsibilities: Respond to emergency and non...
# 1996      California  You will be responsible for a broad range of m...
# 1997            Utah  You will be a driver (pilot) for a commercial ...
# 1998            Ohio  Driving a Carvana car hauler as you deliver ou...
# 1999            Utah  You will have the opportunity to create your o...
#
#                                              hardskills  \
# 0     The ideal candidate for this position will hav...
# 1     The most important background, experience, and...
# 2     As Director of Software Engineering, we are lo...
# 3     A DCS background in the Chemical, Pharmaceutic...
# 4     Siemens is looking for a Corporate Account Man...
# ...                                                 ...
# 1995  * Must have a valid driver's license and clean...
# 1996  Qualifications UPS is hiring individuals to wo...
# 1997  No previous experience required. Lyft does req...
# 1998  – Have a valid driver’s license with a clean d...
# 1999  Lyft Drivers are required to be 21 years or ol...
#
#                                              softskills  \
# 0     We're looking for sharp, passionate, and energ...
# 1     The most important soft skills for success are...
# 2     Answer to this question is required\n\nSiemens...
# 3     1. Excellent customer interfacing skills and n...
# 4     We are looking for a team player with excellen...
# ...                                                 ...
# 1995  Ability to handle stress and emotion in a calm...
# 1996  Customers-Driven Leader-Industrial Engineering...
# 1997  How to Get It:If you shot the video with your ...
# 1998  We’re looking for: Punctuality Reliable Transp...
# 1999  Any basic tips to get started?\n\n1. Be able t...
#
#                                               education
# 0     Not specified  Are you willing to undergo a ba...
# 1     A bachelor's degree in electrical engineering ...
# 2     Bachelor's Degree in Computer Science or equiv...
# 3                 B.S. degree or equivalent experience.
# 4     A bachelor's degree in engineering or business...
# ...                                                 ...
# 1995  + High school diploma or equivalent required +...
# 1996  Industrial Mechanic-Top Pay 41/hr-PensionBenef...
# 1997  No Degree Required: As long as you’re 21 years...
# 1998  Apply For This Job\n\nShare this: Twitter\n\nF...
# 1999  Learn More\n\nWhat education do you need to wo...
#
# [2000 rows x 18 columns]

# %%
# Prepare sql_magic library that enable to query to database easily.
# %reload_ext sql_magic
# %config SQL.conn_name = 'engine'

# %%
# %%read_sql
# show tables;
# Out:
# Query started at 08:50:36 PM UTC; Query executed in 0.00 m
#    Tables_in_Team
# 0  TheMuseAllCats
# 1   TheMuseUSLocs
# 2           Users
# 3         jobdata
# 4     jobdataTEST

# %%
# %%read_sql
# SELECT * FROM TheMuseUSLocs
# Out:
# Query started at 08:50:58 PM UTC; Query executed in 0.00 m
#       index        city state
# 0         0    Aberdeen    MD
# 1         1    Aberdeen    SD
# 2         2    Aberdeen    WA
# 3         3     Abilene    TX
# 4         4         Ada    OK
# ...     ...         ...   ...
# 2186   2186       Yukon    OK
# 2187   2187        Yuma    AZ
# 2188   2188     Zachary    LA
# 2189   2189  Zanesville    OH
# 2190   2190  Zionsville    IN
#
# [2191 rows x 3 columns]

# %%
engine.execute('DROP TABLE IF EXISTS testing')

# %%
# %%read_sql
# SELECT * FROM jobdataTEST
# Out:
# Query started at 03:23:30 AM UTC; Query executed in 0.01 m
#    index                                              title  \
# 0      0  Engineer Commissioning Coordinator- II - Fire/...
# 1      1  Service Specialist II - Smart Buildings / Auto...
# 2      2             Director of Battery Industry Solutions
# 3      3              Service Coordinator - Smart Buildings
# 4      4                                      Driver Helper
# 5      5                      Package Handler – Hiring ASAP
# 6      6                           Seasonal Delivery Driver
# 7      7       Personal Vehicle Driver - Hiring Immediately
#
#                           cat     comp                                loc  \
# 0     Science and Engineering  Siemens                         Cincinnati
# 1                Construction  Siemens                      Buffalo Grove
# 2        Software Engineering  Siemens                             Austin
# 3        Software Engineering  Siemens                         Des Moines
# 4                 Travel Jobs      UPS                 Wells, York County
# 5  Logistics & Warehouse Jobs      UPS         Westford, Middlesex County
# 6                 Travel Jobs      UPS  Barre Junction, Washington County
# 7                 Travel Jobs      UPS             Minoa, Onondaga County
#
#            state                                               desc  \
# 0           Ohio  Engineering Specialist/Technician - Smart Buil...
# 1       Illinois  Who designs your future? You do.   Are you loo...
# 2          Texas  The Solution Director is a Senior, experienced...
# 3           Iowa  Who designs your future? You do.   Are you loo...
# 4          Maine  Driver Helper Wells Beach Station, Maine, US 1...
# 5  Massachusetts  Package Handler – Hiring ASAP Westford, Massac...
# 6        Vermont  Seasonal Delivery Driver Barre, Vermont, US 10...
# 7       New York  Personal Vehicle Driver - Hiring Immediately M...
#
#                                               redURL        lon        lat  \
# 0  https://www.themuse.com/jobs/siemens/engineer-... -84.477144  39.159865
# 1  https://www.themuse.com/jobs/siemens/service-s... -87.952766  42.167687
# 2  https://www.themuse.com/jobs/siemens/director-... -97.809157  30.293807
# 3  https://www.themuse.com/jobs/siemens/service-c... -93.606552  41.588398
# 4  https://www.adzuna.com/land/ad/3748088451?se=w... -70.624838  43.323057
# 5  https://www.adzuna.com/land/ad/3762722531?se=w... -71.443260  42.586980
# 6  https://www.adzuna.com/land/ad/3761031262?se=w... -72.488520  44.191020
# 7  https://www.adzuna.com/land/ad/3762722762?se=w... -76.009879  43.077336
#
#       pstDate salaryPredicted        levels      API  \
# 0  2022-10-11               0  Senior Level  themuse
# 1  2022-11-12               0     Mid Level  themuse
# 2  2022-11-18               0  Senior Level  themuse
# 3  2022-12-06               0     Mid Level  themuse
# 4  2022-12-04               1          None   adzuna
# 5  2022-12-09               1          None   adzuna
# 6  2022-12-09               1          None   adzuna
# 7  2022-12-09               1          None   adzuna
#
#                                                 work  \
# 0  You will support our Smart Buildings organizat...
# 1  Under the direction of your supervisor, you wi...
# 2  • Define battery solutions that span the full ...
# 3  Our Smart Buildings help to create efficient, ...
# 4  You will be working as part of a dynamic and p...
# 5  You’ll lift, lower and slide packages up to 70...
# 6  • Lifting, lowering and carrying packages that...
# 7  • Lift, lower and carry packages up to 70 poun...
#
#                                           hardskills  \
# 0  A high school diploma or state-recognized GED,...
# 1  An Associate's degree or higher in HVAC techno...
# 2  A deep knowledge of the battery industry, engi...
# 3  #LI-KB1   Siemens is an Equal Opportunity and ...
# 4  Extremely customer focused. This job is all ab...
# 5  – UPS Quick Apply Applying for this role onlin...
# 6  • Must be 21 years of age or older • Must have...
# 7  • 21 years of age or older • Valid driver’s li...
#
#                                           softskills  \
# 0  The following are some examples of soft skills...
# 1  - Being able to work in a team environment - P...
# 2  The most important soft skills that are needed...
# 3  Some soft skills that are important for succes...
# 4  Crew Member Wells Beach Station, Maine, US 109...
# 5  The candidate should have a strong work ethic ...
# 6  • Customer service orientation • Good time man...
# 7  Apply Now\n\nUPS Personal Vehicle Drivers Mino...
#
#                                            education
# 0  High school diploma or state-recognized GED re...
# 1  High school diploma or state-recognized GED; A...
# 2  A engineering degree - mechanical, electrical,...
# 3  High school diploma or state-recognized GED re...
# 4  - No formal educational credential\n\nWarehous...
# 5  Apply Online\n\nHow You Can Become a Package H...
# 6  • High school diploma or equivalent • Must be ...
# 7  See full details and how to apply.\n\nPatient ...
